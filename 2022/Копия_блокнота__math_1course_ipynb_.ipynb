# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Решение:
#
# 1.1. <tex>$\lim\limits_{n\to ∞} \frac{21}{3n^2-14n-17}=\lim\limits_{n\to ∞} \frac{1}{n^2} \cdot \frac{21}{3-\frac{14}{n}-\frac{17}{n^2}}=\lim\limits_{n\to ∞} \frac{1}{n^2} \cdot 7 = 0$</tex>
#
# $x_{n+1} - x_n = \frac{21}{3(n+1)^2-14(n+1)-17} - \frac{21}{3n^2-14n-17} = \frac{21}{3n^2-8n-28} - \frac{21}{3n^2-14n-17} = \frac{21}{(3n-14)(n+2)} - \frac{21}{(3n-17)(n+1)} = \frac{21(11-6n)}{(n+1)(n+2)(3n-14)(3n-17)} < 0$
#
# $21(11-6n)=0; n_1 =\frac{11}{6}$
#
# $(n+1)(n+2)(3n-14)(3n-17)=0; n_2 = -1, n_3 = -2, n_4 = \frac{14}{3}, n_5 = \frac{17}{3}.$
#
#
#
#
# 1.2.

# %%
-21/33
# Out:
# -0.6363636363636364

# %%
n = 6
(3*n**2 -14*n-17)
# Out:
# 7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

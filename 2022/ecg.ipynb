# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
x= []
y =[]
with open('/content/drive/MyDrive/cg/emg_3.dat', 'r') as f:
    d = f.readlines()
    for i in d:
        k = i.rstrip().split()
        x += [float(k[0])]
        y += [float(k[1])]

plt.plot(x, y)

# %%
x= []
y =[]
with open('/content/drive/MyDrive/cg/ecg_2.dat', 'r') as f:
    d = f.readlines()
    for i in d:
        k = i.rstrip().split()
        x += [float(k[0])]
        y += [float(k[1])]
x = np.array(x)
y = np.array(y)
plt.plot(x, y)
plt.show()
# plt.plot(x, np.where(y>0.5, 0))
print(x[-1]-x[0])
xs = []
for i, e in enumerate(y.tolist()):
    if e>0.5:
        xs.append(i)
# Out:
# 8.03377

# %%
[x[i] for i in xs]
# Out:
# [4.64146e-05,
#  1.02203,
#  1.03948,
#  2.0426,
#  2.06024,
#  3.00662,
#  4.06559,
#  5.00198,
#  5.95803,
#  7.00268]

# %%
a = []
for i in range(len(xs)-1):
    a += [x[i+1]-x[i]]

# %%
a
# Out:
# [0.016059999999999963,
#  0.01607000000000003,
#  0.01607000000000003,
#  0.016059999999999963,
#  0.01607000000000003,
#  0.016069999999999973,
#  0.01606000000000002,
#  0.016069999999999973,
#  0.01606000000000002]

# %%
60/(sum(a)/len(a))
# Out:
# 3734.6981119026213

# %%
xs
# Out:
# [35, 95, 96, 153, 154, 208, 268, 321, 375, 434]

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("ecg.dat")
a = df[0]
b = df[1]
plt.plot(a,b)
plt.show()
k = np.mean(b)
b = [0 if i < k else 1 for i in b]
print(a[-1] - a[0])
print(b.count(1) / round(a[-1]-a[0]))

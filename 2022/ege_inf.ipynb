# %% [markdown]
# # Задание 12. Исполнители

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = 70*"8"

while "2222" in s or "8888" in s:
    if "2222" in s:
        s = s.replace("2222", "88", 1)
    else:
        s = s.replace("8888", "22", 1)
print(s)
# Out:
# 22

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = "2" + 81*"5"

while "25" in s or "355" in s or "4555" in s:
    if "25" in s: s = s.replace("25", "4", 1)
    if "355" in s: s = s.replace("355", "2", 1)
    if "4555" in s: s = s.replace("4555", "3", 1)
print(s)
# Out:
# 455

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = "1" + 33*"0"

while "1" in s or "100" in s:
    if "100" in s:
        s = s.replace("100", "0001", 1)
    else:
        s = s.replace("1", "00", 1)
print(len(s))
# Out:
# 51

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = "1"*46 + "2"*31

while "1111" in s:
    s = s.replace("1111", "2", 1)
    s = s.replace("222", "1", 1)
print(s)
# Out:
# 12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(1, 51):
    s = i*"6"
    while "66" in s:
        s = s.replace("66", "1", 1)
        s = s.replace("11", "2", 1)
        s = s.replace("22", "6", 1)
    if s == "21":
        print(i)
# Out:
# 6
# 13
# 20
# 27
# 34
# 41
# 48

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = ">" + 11*"1" + 12*"2" + 30*"3"

while ">1" in s or ">2" in s or ">3" in s:
    if ">1" in s: s = s.replace(">1", "22>", 1)
    if ">2" in s: s = s.replace(">2", "2>", 1)
    if ">3" in s: s = s.replace(">3", "1>", 1)

print(2*s.count("2") + s.count("1"))
# Out:
# 98

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def f(s):
    comp = s[:]
    while "01" in s or "02" in s or "03" in s:
        s = s.replace("01", "302", 1)
        s = s.replace("02", "3103", 1)
        s = s.replace("03", "20", 1)
    print(comp, "->", s)
f("01")
f("02")
f("03")
# Out:
# 01 -> 33120
# 02 -> 3120
# 03 -> 20

# %%
45-28
# Out:
# 17

# %%
for x in range(1, 50):
    for y in range(1, 50):
        for z in range(1, 50):
            s = "0" + x*"1" + y*"2" + z*"3"
            while "01" in s or "02" in s or "03" in s:
                s = s.replace("01", "302", 1)
                s = s.replace("02", "3103", 1)
                s = s.replace("03", "20", 1)
            if s.count("1")==28 and s.count("2")==34 and s.count("3")==45:
                print(x)
# Out:
# 17

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = "112"*4 + "1111"

while "11" in s:
    if "112" in s:
        s = s.replace("112", "7", 1)
    else:
        s = s.replace("11", "3", 1)
print(sum(int(a) for a in s))
# Out:
# 34

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = "9992"*33+"2"*15+"9"+"1"*14

while "999" in s or "22" in s:
    if "999" in s:
        s = s.replace("999", "12", 1)
    else:
        s = s.replace("22", "1")
print(s.count("1"))
# Out:
# 87

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(1, 50):
    s = i*"5"
    while "555" in s or "888" in s:
        s = s.replace("555", "8", 1)
        s = s.replace("888", "55", 1)
    print(s)

# 5
# 55
# 8
# 85
# 855
# 88
# 885
# 8855

## Ответ: 8.

# %%
23-7
# Out:
# 16

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = "КАРА"
i = len(a)-1
k = 1
b = "T"
while i > 0:
    c = a[i]
    b += c
    i -= k

print(b)
# Out:
# TАРА

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
a = "ИНФОРМАТИКА"
m = 10-1
b = a[m]
for k in (3, 4):
    c = a[k]
    b += c
for k in range(3):
    c = a[k]
    b += c
print(b)
# Out:
# КОРИНФ
